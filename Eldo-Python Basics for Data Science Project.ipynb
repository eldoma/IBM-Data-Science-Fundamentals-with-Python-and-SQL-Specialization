# %% [markdown]
# # Task 3: Load in the Dataset in your Jupyter Notebook
#
# In the Jupyter notebook you created in the previous task, add a code cell, and copy the contents below to load the Boston housing dataset in the notebook:

# %%
#boston_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
#boston_df=pd.read_csv(boston_url)

# %%
## Import Libraries

# %%
#install specific version of libraries used in lab
! mamba install pandas==1.3.3
! mamba install numpy=1.21.2
! mamba install scipy=1.7.1-y
!  mamba install seaborn=0.9.0-y
!  mamba install matplotlib=3.4.3-y
!  mamba install statsmodels=0.12.0-y
import piplite
await piplite.install(['numpy'])
await piplite.install(['pandas'])
await piplite.install(['seaborn'])
# Out:
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (1.4.2) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['pandas==1.3.3']
#
# [+] 0.0s
# ...

# %%
# !mamba install -y pandas==1.3.3
# !mamba install -y numpy==1.21.2
# !mamba install -y scipy==1.7.1
# !mamba install -y seaborn==0.9.0
# !mamba install -y matplotlib==3.4.3
# !mamba install -y statsmodels==0.12.0
# Out:
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (1.4.2) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['pandas==1.3.3']
#
# [+] 0.0s
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import statsmodels.api as sm

# %%
# !python --version
# Out:
# Python 3.10.13

# %%
import piplite
await piplite.install(['numpy'])
await piplite.install(['pandas'])
await piplite.install(['seaborn'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import piplite
#       2 await piplite.install(['numpy'])
#       3 await piplite.install(['pandas'])
#
# ModuleNotFoundError: No module named 'piplite'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import statsmodels.api as sm

# %%
boston_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
boston_df = pd.read_csv(boston_url)

# %%
boston_df.describe()
# Out:
#        Unnamed: 0        CRIM          ZN       INDUS        CHAS         NOX  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   252.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      0.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    126.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    252.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    378.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    505.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                RM         AGE         DIS         RAD         TAX     PTRATIO  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
# show the first 10 rows
boston_df.head(10)
# Out:
#    Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  \
# 0           0  0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900  1.0
# 1           1  0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671  2.0
# 2           2  0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671  2.0
# 3           3  0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622  3.0
# 4           4  0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622  3.0
# 5           5  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622  3.0
# 6           6  0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605  5.0
# 7           7  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505  5.0
# 8           8  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821  5.0
# 9           9  0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921  5.0
#
#      TAX  PTRATIO  LSTAT  MEDV
# 0  296.0     15.3   4.98  24.0
# 1  242.0     17.8   9.14  21.6
# 2  242.0     17.8   4.03  34.7
# ...

# %% [markdown]
# ## Task 4-Question 1
# For the "Median value of owner-occupied homes" provide a boxplot

# %%
ax = sns.boxplot(y = 'MEDV', data = boston_df)
ax.set_title('Owner-occupied homes')
# Out:
# Text(0.5, 1.0, 'Owner-occupied homes')

# %%
## Task 4-Question 2
Provide a  bar plot for the Charles river variable

# %%
ax2 = sns.countplot(x = 'CHAS', data = boston_df)
ax2.set_title('Number of homes near the Charles River')
# Out:
# Text(0.5, 1.0, 'Number of homes near the Charles River')

# %% [markdown]
# _Histogram shows that the majority of the houses are not near the Charles River._

# %% [markdown]
# ## Task 4-Question 3
# Provide a boxplot for the MEDV variable vs the AGE variable. (Discretize the age variable into three groups of 35 years and younger, between 35 and 70 years and 70 years and older)

# %%
boston_df.loc[(boston_df['AGE'] <= 35), 'Age_Group'] = '35 years and younger'
boston_df.loc[(boston_df['AGE'] > 35) & (boston_df['AGE'] < 70), 'Age_Group'] = 'between 35 and 70 years'
boston_df.loc[(boston_df['AGE'] >= 70), 'Age_Group'] = '70 years and older'

ax3 = sns.boxplot(x = 'MEDV', y = 'Age_Group', data = boston_df)
ax3.set_title('Median value of owner-occupied homes per Age Group')
# Out:
# Text(0.5, 1.0, 'Median value of owner-occupied homes per Age Group')

# %% [markdown]
# _Boxplot above shows that on average the median value of owner occupied homes is higher when the Age is lower._

# %% [markdown]
# ## Task 4-Question 3
# Provide a scatter plot to show the relationship between Nitric oxide concentrations and the proportion of non-retail business acres per town. What can you say about the relationship?

# %%
ax4 = sns.scatterplot(y = 'NOX', x = 'INDUS', data = boston_df)
ax4.set_title('Nitric oxide concentrations vs Proportion of non-retail business acres/town')
# Out:
# Text(0.5, 1.0, 'Nitric oxide concentrations vs Proportion of non-retail business acres/town')

# %% [markdown]
# _The plot shows a positive correlation between the two variables, meaning that as the proportion of non-retail business acres per town increases, so do Nitric oxide concentrations.
# This relationship is likely due to the fact that non-retail businesses, such as factories and power plants, tend to emit more Nitric oxide into the atmosphere. As a result, towns
# with a higher proportion of non-retail businesses tend to have higher Nitric oxide concentrations.
# The scatter plot also shows that there is a significant amount of variation in the data. This means that there are some towns with high proportions of non-retail businesses but
# relatively low Nitric oxide concentrations, and vice versa. This variation is likely due to a number of factors, such as the type of non-retail businesses in the town, the prevailing
# wind patterns, and the presence of other sources of Nitric oxide emissions._
#
# _Overall, the scatter plot suggests that there is a positive relationship between Nitric oxide concentrations and the proportion of non-retail business acres per town.
# However, it is important to note that there is also a significant amount of variation in the data, and that the relationship is likely influenced by a number of other factors._

# %% [markdown]
# ## Task 4-Question 4
# Create a histogram for the pupil to teacher ratio variable

# %%
ax5 = sns.countplot(x = 'PTRATIO', data = boston_df)
ax5.set_title('Histogram for the pupil to teacher ratio variable')
# Out:
# Text(0.5, 1.0, 'Histogram for the pupil to teacher ratio variable')

# %%
## Task 5-Question 1
Is there a significant difference in median value of houses bounded by the Charles river or not? (T-test for independent samples)
# Out:
#   Cell In[33], line 2
#     Is there a significant difference in median value of houses bounded by the Charles river or not? (T-test for independent samples)
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# Answer:
#
#
# Setting up Hypothesis:
#
# Null Hypothesis -> There's no significant difference in median value between houses bounded and not bounded by the Charles River
#
# Alternative Hypothesis -> There's a significant difference in median value between houses bounded and not bounded by the Charles River

# %%
boston_df.loc[(boston_df['CHAS'] == 0), 'CHAS_T'] = 'FAR'
boston_df.loc[(boston_df['CHAS'] == 1), 'CHAS_T'] = 'NEAR'

# %%
scipy.stats.ttest_ind(boston_df[boston_df['CHAS_T'] == 'FAR']['MEDV'], 
                      boston_df[boston_df['CHAS_T'] == 'NEAR']['MEDV'], equal_var = True)
# Out:
# Ttest_indResult(statistic=-3.996437466090509, pvalue=7.390623170519905e-05)

# %% [markdown]
# Answer: the p-value is less than 0.05, so we reject the Null Hypothesis, meaning there is not a statistical difference in median value betwenn houses near the Charles River and houses far away

# %% [markdown]
# ## Task 5-Question 2
# Is there a difference in Median values of houses (MEDV) for each proportion of owner occupied units built prior to 1940 (AGE)? (ANOVA)

# %% [markdown]
# Setting up Hypothesis:
#
# Null Hypotesis: There isn't statistical difference in Median values of houses (MEDV) for each proportion of owner occpied units built prior to 1940
#
# Alternative Hypothesis: There is statistical difference in Median values of houses (MEDV) for each proportion of owner occpied units built prior to 1940

# %%
from statsmodels.formula.api import ols
lm = ols('MEDV ~ AGE', data = boston_df).fit()
table = sm.stats.anova_lm(lm)
print(table)
# Out:
#              df        sum_sq      mean_sq          F        PR(>F)
# AGE         1.0   6069.761065  6069.761065  83.477459  1.569982e-18
# Residual  504.0  36646.534350    72.711378        NaN           NaN

# %% [markdown]
# Given p-value is less than 0.05, we fail to accept the Null Hypothesis.
#
# Answer: There is statistical difference in Median values of houses (MEDV) for each proportion of owner occpied units built prior to 1940

# %% [markdown]
# ## Task 5-Question 3
# Can we conclude that there is no relationship between Nitric oxide concentrations and proportion of non-retail business acres per town? (Pearson Correlation)

# %% [markdown]
# Null Hypothesis: Nitric Oxide concentration is not correlated with the proportion of non-retail business acres per town
#
# Alternative Hypothesis: Nitric Oxide concentration is correlated with the proportion of non-retail business acres per town

# %%
scipy.stats.pearsonr(boston_df['NOX'], boston_df['INDUS'])
# Out:
# PearsonRResult(statistic=0.7636514469209151, pvalue=7.913361061239527e-98)

# %% [markdown]
# Answer : Given the Pearson Coefficient is 0.76365 and p-value less than 0.05, we reject the Null Hypothesis as there is a positive correlation between Nitric oxide concentration and proportion of non-retail business acres per town

# %% [markdown]
# ## Task 5-Question 4
# What is the impact of an additional weighted distance  to the five Boston employment centres on the median value of owner occupied homes? (Regression analysis)

# %%
x = boston_df['DIS']
y = boston_df['MEDV']

x = sm.add_constant(x)

model = sm.OLS(y, x).fit()
predisction = model.predict(x)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.062
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     33.58
# Date:                Mon, 20 Nov 2023   Prob (F-statistic):           1.21e-08
# Time:                        11:05:58   Log-Likelihood:                -1823.9
# No. Observations:                 506   AIC:                             3652.
# Df Residuals:                     504   BIC:                             3660.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         18.3901      0.817     22.499      0.000      16.784      19.996
# ...

# %% [markdown]
# The coefficient (DIS) of 1.0916 indicates that an additional weighted distance to the 5 employment centers in boston increases of 1.0916 the median value of owner occupied homes.
